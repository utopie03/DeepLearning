# %% [markdown]
# ### 利用卷积神经网络（Convolutional Neural Network，CNN）实现垃圾图片分类

# %% [markdown]
# 在这个项目中，我们将通过使用`CNN`，对垃圾图片进行高效分类。本数据集包含六种不同类型的垃圾，分别为玻璃、纸、硬纸板、塑料、金属以及一般垃圾，在`"D:\深度学习\data"`目录下。

# %%
# type: ignore
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow.keras as keras
import glob, os, random
import tensorflow as tf
from keras.preprocessing.image import (
    ImageDataGenerator,
    load_img,
    img_to_array,
    array_to_img,
)
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from keras.models import Sequential
from keras.models import load_model
from tensorflow.keras import layers, Sequential, regularizers

from tensorflow.keras.optimizers import SGD

# %% [markdown]
# #### 1. 加载数据集

# %% [markdown]
#     使用 glob 函数来获取指定文件夹下所有 .jpg 格式的图片路径，并打印出图片数量

# %%
base_path = "D:\深度学习\data\dataset"
img_list = glob.glob(os.path.join(base_path, "*/*.jpg"))
print(len(img_list))
# Out:
# 2527

# %% [markdown]
# #### 2. 可视化随机样本

# %% [markdown]
# 从加载的图像列表中随机选择一些样本，并将其可视化，以便更好地理解数据。
# - 使用 random.sample 函数来随机选择 6 张图片进行可视化
# - 使用 load_img 函数将图像加载为对象，然后将其转换为 NumPy 数组
# - 使用 plt.imshow 函数来显示图像

# %%
for i, img_path in enumerate(random.sample(img_list, 6)):
    img = load_img(img_path)
    img = img_to_array(img, dtype=np.uint8)

    plt.subplot(2, 3, i + 1)
    # 调整子图布局 https://blog.csdn.net/mighty13/article/details/116147658
    plt.tight_layout()
    plt.imshow(img.squeeze())

# %% [markdown]
# #### 3. 数据预处理与生成器

# %% [markdown]
#     使用 ImageDataGenerator 对象来创建生成器，将数据预处理步骤包括在内

# %%
train_datagen = ImageDataGenerator(
    # 对图片的每个像素值均乘上这个放缩因子，把像素值放缩到0和1之间有利于模型的收敛
    rescale=1.0 / 225,
    # 浮点数，剪切强度（逆时针方向的剪切变换角度）
    shear_range=0.1,
    # 随机缩放的幅度，若为浮点数，则相当于[lower,upper] = [1 - zoom_range, 1+zoom_range]
    zoom_range=0.1,
    # 浮点数，图片宽度的某个比例，数据提升时图片水平偏移的幅度
    width_shift_range=0.1,
    # 浮点数，图片高度的某个比例，数据提升时图片竖直偏移的幅度
    height_shift_range=0.1,
    # 布尔值，进行随机水平翻转
    horizontal_flip=True,
    # 布尔值，进行随机竖直翻转
    vertical_flip=True,
    # 在 0 和 1 之间浮动。用作验证集的训练数据的比例
    validation_split=0.1,
)

test_datagen = ImageDataGenerator(rescale=1.0 / 255, validation_split=0.1)

train_generator = train_datagen.flow_from_directory(
    # 提供的路径下面需要有子目录
    base_path,
    # 整数元组 (height, width)，默认：(256, 256)。 所有的图像将被调整到的尺寸。
    target_size=(300, 300),
    # 一批数据的大小
    batch_size=32,
    # "categorical", "binary", "sparse", "input" 或 None 之一。
    # 默认："categorical",返回one-hot 编码标签。
    class_mode="categorical",
    # 数据子集 ("training" 或 "validation")
    subset="training",
    seed=0,
)

validation_generator = test_datagen.flow_from_directory(
    base_path,
    target_size=(300, 300),
    batch_size=32,
    class_mode="categorical",
    subset="validation",
    seed=0,
)
# Out:
# Found 2276 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.

# %% [markdown]
#     输出类别索引的字典。其中键是类别的数字索引，值是对应的类别名称

# %%
labels = train_generator.class_indices
labels = dict((v, k) for k, v in labels.items())

print(labels)
# Out:
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %% [markdown]
# #### 4. 构建CNN模型

# %% [markdown]
# CNN模型由多个卷积层、池化层和全连接层组成，从而能够逐步提取图像中的特征，并在全连接层中进行分类。

# %% [markdown]
#     使用 Sequential 模型，将一系列的卷积层、池化层和全连接层逐一堆叠起来

# %%
model = Sequential(
    [
        Conv2D(
            filters=32,
            kernel_size=3,
            padding="same",
            activation="relu",
            input_shape=(300, 300, 3),
        ),
        MaxPooling2D(pool_size=2),
        Conv2D(filters=64, kernel_size=3, padding="same", activation="relu"),
        MaxPooling2D(pool_size=2),
        Conv2D(filters=32, kernel_size=3, padding="same", activation="relu"),
        MaxPooling2D(pool_size=2),
        Conv2D(filters=32, kernel_size=3, padding="same", activation="relu"),
        MaxPooling2D(pool_size=2),
        Flatten(),
        Dense(64, activation="relu"),
        Dense(6, activation="softmax"),
    ]
)

# %% [markdown]
# #### 5. 编译模型

# %% [markdown]
# - 使用交叉熵损失函数（categorical_crossentropy）作为目标函数，用于多类别分类问题。
# - **优化器选择 Adam/SGD**
# - 评估指标选择准确率（acc）

# %%
# 编译模型, 采用 compile 函数: https://keras.io/models/model/#compile
model.compile(
    # 损失函数,多分类采用 categorical_crossentropy
    loss="categorical_crossentropy",
    # 优化器, 主要有Adam、sgd、rmsprop等方式
    # optimizer="Adam",
    optimizer=SGD(learning_rate=1e-3, momentum=0.9),
    # optimizer = "rmsprop",
    # 是除了损失函数值之外的特定指标, 分类问题一般都是准确率
    metrics=["acc"],
)

# %% [markdown]
# #### 6. 训练模型

# %% [markdown]
#     使用生成器 train_generator 和 validation_generator 来训练模型。设置训练轮数为 100 轮，以及适当的批次大小和步数

# %%
history = model.fit(
    # 一个生成器或 Sequence 对象的实例
    train_generator,
    # epochs: 整数，数据的迭代总轮数。
    epochs=100,
    # 一个epoch包含的步数,通常应该等于数据集的样本数量除以批量大小。
    steps_per_epoch=2276 // 32,
    # 验证集
    validation_data=validation_generator,
    # 在验证集上,一个epoch包含的步数,通常应该等于数据集的样本数量除以批量大小。
    validation_steps=251 // 32,
)
# Out:
# Epoch 1/100
# 71/71 [==============================] - 34s 407ms/step - loss: 1.7309 - acc: 0.2277 - val_loss: 1.7048 - val_acc: 0.2768
# Epoch 2/100
# 71/71 [==============================] - 29s 405ms/step - loss: 1.6539 - acc: 0.3017 - val_loss: 1.6016 - val_acc: 0.2991
# Epoch 3/100
# 71/71 [==============================] - 29s 406ms/step - loss: 1.5307 - acc: 0.3801 - val_loss: 1.5145 - val_acc: 0.3304
# Epoch 4/100
# 71/71 [==============================] - 29s 407ms/step - loss: 1.4837 - acc: 0.3837 - val_loss: 1.4874 - val_acc: 0.3929
# Epoch 5/100
# 71/71 [==============================] - 29s 409ms/step - loss: 1.4420 - acc: 0.4269 - val_loss: 1.4580 - val_acc: 0.4018
# Epoch 6/100
# 71/71 [==============================] - 29s 412ms/step - loss: 1.3845 - acc: 0.4416 - val_loss: 1.3947 - val_acc: 0.3884
# Epoch 7/100
# 71/71 [==============================] - 29s 411ms/step - loss: 1.3451 - acc: 0.4701 - val_loss: 1.3912 - val_acc: 0.4464
# Epoch 8/100
# 71/71 [==============================] - 29s 406ms/step - loss: 1.2986 - acc: 0.4862 - val_loss: 1.3989 - val_acc: 0.4509
# Epoch 9/100
# 71/71 [==============================] - 29s 403ms/step - loss: 1.2669 - acc: 0.4978 - val_loss: 1.3612 - val_acc: 0.5179
# Epoch 10/100
# 71/71 [==============================] - 29s 404ms/step - loss: 1.2996 - acc: 0.4857 - val_loss: 1.5370 - val_acc: 0.3616
# Epoch 11/100
# 71/71 [==============================] - 29s 409ms/step - loss: 1.2469 - acc: 0.5152 - val_loss: 1.3218 - val_acc: 0.4375
# Epoch 12/100
# 71/71 [==============================] - 29s 405ms/step - loss: 1.2372 - acc: 0.5276 - val_loss: 1.2703 - val_acc: 0.5179
# Epoch 13/100
# 71/71 [==============================] - 29s 405ms/step - loss: 1.2006 - acc: 0.5321 - val_loss: 1.2001 - val_acc: 0.5714
# Epoch 14/100
# 71/71 [==============================] - 29s 408ms/step - loss: 1.1715 - acc: 0.5517 - val_loss: 1.2781 - val_acc: 0.5625
# Epoch 15/100
# 71/71 [==============================] - 29s 410ms/step - loss: 1.1622 - acc: 0.5499 - val_loss: 1.4077 - val_acc: 0.4688
# Epoch 16/100
# 71/71 [==============================] - 29s 410ms/step - loss: 1.1050 - acc: 0.5807 - val_loss: 1.2865 - val_acc: 0.4911
# Epoch 17/100
# 71/71 [==============================] - 29s 414ms/step - loss: 1.1237 - acc: 0.5704 - val_loss: 1.1835 - val_acc: 0.5670
# Epoch 18/100
# 71/71 [==============================] - 30s 417ms/step - loss: 1.1410 - acc: 0.5584 - val_loss: 1.2858 - val_acc: 0.5000
# Epoch 19/100
# 71/71 [==============================] - 29s 408ms/step - loss: 1.0787 - acc: 0.5945 - val_loss: 1.4374 - val_acc: 0.4777
# Epoch 20/100
# 71/71 [==============================] - 29s 412ms/step - loss: 1.0415 - acc: 0.6101 - val_loss: 1.2629 - val_acc: 0.5446
# Epoch 21/100
# 71/71 [==============================] - 30s 415ms/step - loss: 1.0586 - acc: 0.5967 - val_loss: 1.1286 - val_acc: 0.6027
# Epoch 22/100
# 71/71 [==============================] - 30s 416ms/step - loss: 1.0178 - acc: 0.6248 - val_loss: 1.0611 - val_acc: 0.6071
# Epoch 23/100
# 71/71 [==============================] - 30s 417ms/step - loss: 1.0229 - acc: 0.6101 - val_loss: 1.1410 - val_acc: 0.5759
# Epoch 24/100
# 71/71 [==============================] - 30s 417ms/step - loss: 1.0127 - acc: 0.6257 - val_loss: 1.0698 - val_acc: 0.6339
# Epoch 25/100
# 71/71 [==============================] - 30s 417ms/step - loss: 0.9899 - acc: 0.6257 - val_loss: 1.1034 - val_acc: 0.6071
# Epoch 26/100
# 71/71 [==============================] - 30s 417ms/step - loss: 0.9977 - acc: 0.6261 - val_loss: 1.0338 - val_acc: 0.6205
# Epoch 27/100
# 71/71 [==============================] - 30s 419ms/step - loss: 1.0751 - acc: 0.6016 - val_loss: 1.0428 - val_acc: 0.6161
# Epoch 28/100
# 71/71 [==============================] - 30s 415ms/step - loss: 1.0004 - acc: 0.6315 - val_loss: 1.0309 - val_acc: 0.6071
# Epoch 29/100
# 71/71 [==============================] - 30s 416ms/step - loss: 0.9558 - acc: 0.6390 - val_loss: 1.0750 - val_acc: 0.6250
# Epoch 30/100
# 71/71 [==============================] - 29s 411ms/step - loss: 0.9889 - acc: 0.6332 - val_loss: 1.1100 - val_acc: 0.6071
# Epoch 31/100
# 71/71 [==============================] - 30s 428ms/step - loss: 0.9530 - acc: 0.6408 - val_loss: 1.2609 - val_acc: 0.5402
# Epoch 32/100
# 71/71 [==============================] - 29s 412ms/step - loss: 0.9501 - acc: 0.6413 - val_loss: 1.0249 - val_acc: 0.6696
# Epoch 33/100
# 71/71 [==============================] - 31s 432ms/step - loss: 0.9463 - acc: 0.6480 - val_loss: 1.0236 - val_acc: 0.6607
# Epoch 34/100
# 71/71 [==============================] - 30s 420ms/step - loss: 0.9355 - acc: 0.6533 - val_loss: 1.1600 - val_acc: 0.5982
# Epoch 35/100
# 71/71 [==============================] - 29s 403ms/step - loss: 0.9320 - acc: 0.6471 - val_loss: 1.2240 - val_acc: 0.5714
# Epoch 36/100
# 71/71 [==============================] - 29s 406ms/step - loss: 0.9251 - acc: 0.6631 - val_loss: 1.0451 - val_acc: 0.6384
# Epoch 37/100
# 71/71 [==============================] - 28s 399ms/step - loss: 0.8873 - acc: 0.6729 - val_loss: 1.1533 - val_acc: 0.6116
# Epoch 38/100
# 71/71 [==============================] - 28s 400ms/step - loss: 0.8789 - acc: 0.6756 - val_loss: 0.9498 - val_acc: 0.6696
# Epoch 39/100
# 71/71 [==============================] - 28s 398ms/step - loss: 0.8860 - acc: 0.6783 - val_loss: 1.0177 - val_acc: 0.6562
# Epoch 40/100
# 71/71 [==============================] - 28s 398ms/step - loss: 0.8738 - acc: 0.6840 - val_loss: 1.2376 - val_acc: 0.5223
# Epoch 41/100
# 71/71 [==============================] - 30s 425ms/step - loss: 0.8444 - acc: 0.6832 - val_loss: 1.0393 - val_acc: 0.5982
# Epoch 42/100
# 71/71 [==============================] - 31s 428ms/step - loss: 0.8592 - acc: 0.6800 - val_loss: 1.0361 - val_acc: 0.6429
# Epoch 43/100
# 71/71 [==============================] - 30s 424ms/step - loss: 0.8435 - acc: 0.6889 - val_loss: 1.0666 - val_acc: 0.6250
# Epoch 44/100
# 71/71 [==============================] - 29s 405ms/step - loss: 0.8054 - acc: 0.7054 - val_loss: 1.1757 - val_acc: 0.5804
# Epoch 45/100
# 71/71 [==============================] - 29s 404ms/step - loss: 0.8390 - acc: 0.6849 - val_loss: 0.9049 - val_acc: 0.6741
# Epoch 46/100
# 71/71 [==============================] - 29s 405ms/step - loss: 0.8389 - acc: 0.6863 - val_loss: 0.9147 - val_acc: 0.6562
# Epoch 47/100
# 71/71 [==============================] - 30s 416ms/step - loss: 0.8097 - acc: 0.6983 - val_loss: 0.9540 - val_acc: 0.6473
# Epoch 48/100
# 71/71 [==============================] - 29s 409ms/step - loss: 0.8394 - acc: 0.6894 - val_loss: 0.9008 - val_acc: 0.6562
# Epoch 49/100
# 71/71 [==============================] - 29s 404ms/step - loss: 0.8202 - acc: 0.6952 - val_loss: 0.8973 - val_acc: 0.6786
# Epoch 50/100
# 71/71 [==============================] - 30s 417ms/step - loss: 0.8248 - acc: 0.6906 - val_loss: 0.9951 - val_acc: 0.6786
# Epoch 51/100
# 71/71 [==============================] - 29s 409ms/step - loss: 0.7833 - acc: 0.7081 - val_loss: 0.9958 - val_acc: 0.6339
# Epoch 52/100
# 71/71 [==============================] - 29s 409ms/step - loss: 0.8504 - acc: 0.6925 - val_loss: 1.5787 - val_acc: 0.4643
# Epoch 53/100
# 71/71 [==============================] - 29s 407ms/step - loss: 0.9453 - acc: 0.6332 - val_loss: 0.9298 - val_acc: 0.6741
# Epoch 54/100
# 71/71 [==============================] - 29s 409ms/step - loss: 0.7549 - acc: 0.7184 - val_loss: 1.0170 - val_acc: 0.5893
# Epoch 55/100
# 71/71 [==============================] - 29s 412ms/step - loss: 0.7581 - acc: 0.7277 - val_loss: 0.9439 - val_acc: 0.6607
# Epoch 56/100
# 71/71 [==============================] - 29s 411ms/step - loss: 0.7492 - acc: 0.7268 - val_loss: 0.8977 - val_acc: 0.6875
# Epoch 57/100
# 71/71 [==============================] - 29s 410ms/step - loss: 0.7228 - acc: 0.7380 - val_loss: 0.9853 - val_acc: 0.6652
# Epoch 58/100
# 71/71 [==============================] - 29s 411ms/step - loss: 0.7365 - acc: 0.7255 - val_loss: 0.9470 - val_acc: 0.6607
# Epoch 59/100
# 71/71 [==============================] - 29s 413ms/step - loss: 0.7420 - acc: 0.7197 - val_loss: 0.9807 - val_acc: 0.6473
# Epoch 60/100
# 71/71 [==============================] - 29s 405ms/step - loss: 0.6970 - acc: 0.7442 - val_loss: 0.9019 - val_acc: 0.6964
# Epoch 61/100
# 71/71 [==============================] - 29s 407ms/step - loss: 0.6904 - acc: 0.7527 - val_loss: 0.9631 - val_acc: 0.6607
# Epoch 62/100
# 71/71 [==============================] - 29s 409ms/step - loss: 0.6881 - acc: 0.7402 - val_loss: 0.8940 - val_acc: 0.6696
# Epoch 63/100
# 71/71 [==============================] - 29s 407ms/step - loss: 0.6826 - acc: 0.7464 - val_loss: 1.1270 - val_acc: 0.6339
# Epoch 64/100
# 71/71 [==============================] - 29s 404ms/step - loss: 0.7039 - acc: 0.7402 - val_loss: 0.8276 - val_acc: 0.7232
# Epoch 65/100
# 71/71 [==============================] - 29s 412ms/step - loss: 0.6583 - acc: 0.7567 - val_loss: 0.9069 - val_acc: 0.6741
# Epoch 66/100
# 71/71 [==============================] - 31s 429ms/step - loss: 0.6667 - acc: 0.7464 - val_loss: 1.2019 - val_acc: 0.6384
# Epoch 67/100
# 71/71 [==============================] - 29s 405ms/step - loss: 0.6975 - acc: 0.7504 - val_loss: 0.8112 - val_acc: 0.7054
# Epoch 68/100
# 71/71 [==============================] - 29s 409ms/step - loss: 0.6770 - acc: 0.7473 - val_loss: 0.9432 - val_acc: 0.6830
# Epoch 69/100
# 71/71 [==============================] - 29s 406ms/step - loss: 0.6956 - acc: 0.7433 - val_loss: 0.8629 - val_acc: 0.6696
# Epoch 70/100
# 71/71 [==============================] - 29s 413ms/step - loss: 0.6221 - acc: 0.7727 - val_loss: 0.9717 - val_acc: 0.6741
# Epoch 71/100
# 71/71 [==============================] - 30s 415ms/step - loss: 0.6415 - acc: 0.7602 - val_loss: 1.0220 - val_acc: 0.6339
# Epoch 72/100
# 71/71 [==============================] - 29s 417ms/step - loss: 0.6233 - acc: 0.7669 - val_loss: 0.8573 - val_acc: 0.7098
# Epoch 73/100
# 71/71 [==============================] - 29s 412ms/step - loss: 0.6266 - acc: 0.7669 - val_loss: 1.1487 - val_acc: 0.5982
# Epoch 74/100
# 71/71 [==============================] - 29s 410ms/step - loss: 0.6242 - acc: 0.7718 - val_loss: 0.9153 - val_acc: 0.6786
# Epoch 75/100
# 71/71 [==============================] - 29s 411ms/step - loss: 0.6197 - acc: 0.7705 - val_loss: 0.8543 - val_acc: 0.6920
# Epoch 76/100
# 71/71 [==============================] - 30s 422ms/step - loss: 0.6144 - acc: 0.7794 - val_loss: 0.9718 - val_acc: 0.6741
# Epoch 77/100
# 71/71 [==============================] - 29s 413ms/step - loss: 0.6093 - acc: 0.7746 - val_loss: 1.1603 - val_acc: 0.5982
# Epoch 78/100
# 71/71 [==============================] - 29s 412ms/step - loss: 0.5779 - acc: 0.7963 - val_loss: 0.9346 - val_acc: 0.7054
# Epoch 79/100
# 71/71 [==============================] - 30s 417ms/step - loss: 0.5904 - acc: 0.7825 - val_loss: 0.9773 - val_acc: 0.6518
# Epoch 80/100
# 71/71 [==============================] - 29s 407ms/step - loss: 0.5841 - acc: 0.7910 - val_loss: 0.8110 - val_acc: 0.7098
# Epoch 81/100
# 71/71 [==============================] - 29s 404ms/step - loss: 0.5721 - acc: 0.7879 - val_loss: 0.9317 - val_acc: 0.6786
# Epoch 82/100
# 71/71 [==============================] - 29s 404ms/step - loss: 0.5702 - acc: 0.7830 - val_loss: 0.9119 - val_acc: 0.7188
# Epoch 83/100
# 71/71 [==============================] - 29s 405ms/step - loss: 0.5858 - acc: 0.7821 - val_loss: 0.9178 - val_acc: 0.6920
# Epoch 84/100
# 71/71 [==============================] - 29s 402ms/step - loss: 0.5603 - acc: 0.7959 - val_loss: 0.9941 - val_acc: 0.6518
# Epoch 85/100
# 71/71 [==============================] - 29s 402ms/step - loss: 0.5956 - acc: 0.7857 - val_loss: 1.1788 - val_acc: 0.5982
# Epoch 86/100
# 71/71 [==============================] - 29s 409ms/step - loss: 0.7594 - acc: 0.7304 - val_loss: 0.8852 - val_acc: 0.6920
# Epoch 87/100
# 71/71 [==============================] - 29s 404ms/step - loss: 0.5806 - acc: 0.7901 - val_loss: 1.0900 - val_acc: 0.6473
# Epoch 88/100
# 71/71 [==============================] - 29s 407ms/step - loss: 0.5384 - acc: 0.8133 - val_loss: 1.1969 - val_acc: 0.6250
# Epoch 89/100
# 71/71 [==============================] - 29s 410ms/step - loss: 0.5739 - acc: 0.7883 - val_loss: 1.0483 - val_acc: 0.6830
# Epoch 90/100
# 71/71 [==============================] - 29s 409ms/step - loss: 0.5554 - acc: 0.8004 - val_loss: 0.8657 - val_acc: 0.6786
# Epoch 91/100
# 71/71 [==============================] - 29s 411ms/step - loss: 0.5328 - acc: 0.8066 - val_loss: 1.1754 - val_acc: 0.6250
# Epoch 92/100
# 71/71 [==============================] - 29s 410ms/step - loss: 0.5464 - acc: 0.8008 - val_loss: 1.5129 - val_acc: 0.5312
# Epoch 93/100
# 71/71 [==============================] - 29s 410ms/step - loss: 0.5984 - acc: 0.7834 - val_loss: 0.9696 - val_acc: 0.6607
# Epoch 94/100
# 71/71 [==============================] - 29s 411ms/step - loss: 0.5316 - acc: 0.8048 - val_loss: 1.0538 - val_acc: 0.6250
# Epoch 95/100
# 71/71 [==============================] - 29s 419ms/step - loss: 0.4979 - acc: 0.8231 - val_loss: 1.1048 - val_acc: 0.6607
# Epoch 96/100
# 71/71 [==============================] - 29s 412ms/step - loss: 0.5103 - acc: 0.8173 - val_loss: 1.0350 - val_acc: 0.6518
# Epoch 97/100
# 71/71 [==============================] - 29s 411ms/step - loss: 0.5131 - acc: 0.8168 - val_loss: 0.9321 - val_acc: 0.6786
# Epoch 98/100
# 71/71 [==============================] - 29s 412ms/step - loss: 0.5004 - acc: 0.8115 - val_loss: 1.0098 - val_acc: 0.6830
# Epoch 99/100
# 71/71 [==============================] - 29s 412ms/step - loss: 0.4794 - acc: 0.8289 - val_loss: 0.8994 - val_acc: 0.7411
# Epoch 100/100
# 71/71 [==============================] - 29s 410ms/step - loss: 0.4800 - acc: 0.8275 - val_loss: 1.0032 - val_acc: 0.6696

# %% [markdown]
# #### 7. 保存模型

# %%
save_model_path = "D:\深度学习\models\model_sgd100.h5"  # 保存模型路径和名称
model.save(save_model_path)

# %% [markdown]
# #### 8. 模型评估

# %% [markdown]
#     这里选择了一个批次的测试数据，即批次编号为 1 的测试数据

# %% [markdown]
# 从验证数据生成器中获取一个批次的测试数据，包括图像数据和相应的真实标签

# %%
test_x, test_y = validation_generator.__getitem__(1)

# %% [markdown]
#     使用model.evaluate函数评估模型

# %%
loss, accuracy = model.evaluate(test_x, test_y)
print("\nLoss: %.2f, Accuracy: %.2f%%" % (loss, accuracy * 100))
# Out:
# 1/1 [==============================] - 0s 171ms/step - loss: 0.5998 - acc: 0.7188
#
# Loss: 0.60, Accuracy: 71.88%

# %%
loss, accuracy = model.evaluate(validation_generator)
print("\nLoss: %.2f, Accuracy: %.2f%%" % (loss, accuracy * 100))
# Out:
# 8/8 [==============================] - 2s 209ms/step - loss: 0.9915 - acc: 0.6693
#
# Loss: 0.99, Accuracy: 66.93%

# %% [markdown]
#     accuracy/loss曲线

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.plot(epochs,acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# #### 9. 模型预测

# %% [markdown]
#     使用训练好的模型对测试数据进行预测

# %%
preds = model.predict(test_x)

# %% [markdown]
#     可视化预测结果

# %%
plt.figure(figsize=(16, 16))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.title(
        "pred:%s / truth:%s"
        % (labels[np.argmax(preds[i])], labels[np.argmax(test_y[i])])
    )
    plt.imshow(test_x[i])

# %%
model=load_model("D:\深度学习\models\model_rmsprop100.h5")
test_x, test_y = validation_generator.__getitem__(1)
loss, accuracy = model.evaluate(test_x, test_y)
print("\nLoss: %.2f, Accuracy: %.2f%%" % (loss, accuracy * 100))

loss, accuracy = model.evaluate(validation_generator)
print("\nLoss: %.2f, Accuracy: %.2f%%" % (loss, accuracy * 100))
# Out:
# 1/1 [==============================] - 0s 251ms/step - loss: 0.6861 - acc: 0.8125
#
# Loss: 0.69, Accuracy: 81.25%
# 8/8 [==============================] - 1s 69ms/step - loss: 1.0576 - acc: 0.7769
#
# Loss: 1.06, Accuracy: 77.69%
